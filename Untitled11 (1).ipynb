# %%
import requests
from IPython.display import display, HTML

url = "https://dchtoons.com/"
html = requests.get(url, headers={"User-Agent": "Mozilla/5.0"}).text
print(html)            # raw source
# display(HTML(html))  # render it
# Out:
# <!doctype html>
# <html class="js" lang="en">
#   <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width,initial-scale=1">
#     <meta name="theme-color" content="">
#     <link rel="canonical" href="https://dchtoons.com/"><link rel="icon" type="image/png" href="//dchtoons.com/cdn/shop/files/DCHTOONS_favicon.png?crop=center&height=32&v=1751535534&width=32"><link rel="preconnect" href="https://fonts.shopifycdn.com" crossorigin><title>
#       DCHTOONS
# </title>
#
#
#       <meta name="description" content="Shop cute, quirky and relatable merchandise illustrated by Dylan, a Singapore-based artist and graphic designer. DCHTOONS aims to bring laughter and joy through its creative designs while glamourising every boring surface possible!">
#
#
#
#
# <meta property="og:site_name" content="DCHTOONS">
# <meta property="og:url" content="https://dchtoons.com/">
# ...
